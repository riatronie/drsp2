# %% [markdown]
# <a href="https://colab.research.google.com/github/riatronie/drsp2/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
import pandas as pd

# %%
url='https://github.com/frontiertechinstitute/datasets/raw/main/NHANES%202017-2018%20Data/nhanes_2017_2018_healthy_habits_cleaned.csv'

df = pd.read_csv(url)

df.head(10)
# Out:
#     age  gender  sleep_hours_weekday   bmi  systolic_bp  diastolic_bp  \
# 0   2.0  Female                  NaN  17.5          NaN           NaN
# 1   2.0    Male                  NaN  15.7          NaN           NaN
# 2  66.0  Female                  8.0  31.7          NaN           NaN
# 3  18.0    Male                 10.5  21.5        112.0          74.0
# 4  13.0    Male                  NaN  18.1        128.0          38.0
# 5  66.0  Female                  8.0  23.7          NaN           NaN
# 6  75.0  Female                  7.0  38.9        120.0          66.0
# 7  56.0    Male                  7.0  21.3        108.0          68.0
# 8  18.0    Male                  7.5  19.7        112.0          68.0
# 9  67.0    Male                  5.5  23.5        104.0          70.0
#
#    minutes_sedentary_daily vigorous_recreational_activity  \
# 0                      NaN                            NaN
# 1                      NaN                            NaN
# ...

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=df)
# Out:
# https://docs.google.com/spreadsheets/d/1uLHyNDuNlMRCYu7lhx3xpEG8JBtuvqg18toZoW-R9hA/edit#gid=0
#         <iframe
#             width="100%"
#             height="600"
#             src="https://docs.google.com/spreadsheets/d/1uLHyNDuNlMRCYu7lhx3xpEG8JBtuvqg18toZoW-R9hA/edit?rm=embedded#gid=0"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
print(df.columns)
# Out:
# Index(['age', 'gender', 'sleep_hours_weekday', 'bmi', 'systolic_bp',
#        'diastolic_bp', 'minutes_sedentary_daily',
#        'vigorous_recreational_activity', 'moderate_recreational_activity',
#        'walk_or_bicycle', 'general_health', 'feel_hopeless', 'feel_depressed',
#        'feel_anxious', 'diet_quality', 'fast_food_meals_per_week',
#        'daily_sugar_grams', 'daily_fiber_grams', 'daily_fat_grams',
#        'daily_protein_grams'],
#       dtype='object')

# %%
df.columns = df.columns.str.lower().str.replace(' ','_')

# %%
print(df.isna().sum())
# Out:
# _a_g_e_                                                             0
# _g_e_n_d_e_r_                                                       0
# _s_l_e_e_p___h_o_u_r_s___w_e_e_k_d_a_y_                          2583
# _b_m_i_                                                           361
# _s_y_s_t_o_l_i_c___b_p_                                          2064
# _d_i_a_s_t_o_l_i_c___b_p_                                        2064
# _m_i_n_u_t_e_s___s_e_d_e_n_t_a_r_y___d_a_i_l_y_                  2875
# _v_i_g_o_r_o_u_s___r_e_c_r_e_a_t_i_o_n_a_l___a_c_t_i_v_i_t_y_    2833
# _m_o_d_e_r_a_t_e___r_e_c_r_e_a_t_i_o_n_a_l___a_c_t_i_v_i_t_y_    2833
# _w_a_l_k___o_r___b_i_c_y_c_l_e_                                  2833
# _g_e_n_e_r_a_l___h_e_a_l_t_h_                                    2402
# _f_e_e_l___h_o_p_e_l_e_s_s_                                      3279
# _f_e_e_l___d_e_p_r_e_s_s_e_d_                                    3230
# ...

# %%
df_clean=df.dropna()

# %%
print("Cleaned Data Shape:",)
df_clean.head()
# Out:
# Cleaned Data Shape: (2814, 20)
#     _a_g_e_ _g_e_n_d_e_r_  _s_l_e_e_p___h_o_u_r_s___w_e_e_k_d_a_y_  _b_m_i_  \
# 3      18.0          Male                                     10.5     21.5
# 7      56.0          Male                                      7.0     21.3
# 8      18.0          Male                                      7.5     19.7
# 13     22.0          Male                                      8.0     24.5
# 17     60.0        Female                                      9.0     35.9
#
#     _s_y_s_t_o_l_i_c___b_p_  _d_i_a_s_t_o_l_i_c___b_p_  \
# 3                     112.0                       74.0
# 7                     108.0                       68.0
# 8                     112.0                       68.0
# 13                    116.0                       62.0
# 17                    132.0                       68.0
#
#     _m_i_n_u_t_e_s___s_e_d_e_n_t_a_r_y___d_a_i_l_y_  \
# 3                                             240.0
# ...

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=df_clean)
# Out:
# https://docs.google.com/spreadsheets/d/1ZIT1FYRqMKT6NILto39hA3Env23LaXJuiwKVPEUpLEk/edit#gid=0
#         <iframe
#             width="100%"
#             height="600"
#             src="https://docs.google.com/spreadsheets/d/1ZIT1FYRqMKT6NILto39hA3Env23LaXJuiwKVPEUpLEk/edit?rm=embedded#gid=0"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
